# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ## **Objectives:**
# * List popular languages for Data Scientists
# * List commonly used libraries
# * List Data Science tools
# * Evaluate a few basic arithmetic expressions

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Javascript

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. Numpy
# 3. SciPy
# 4. Matplotlib

# %% [markdown]
# ### Data Science Tools
#  | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Zeppelin    |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# This a simple arithmetic expression to mutiply then add integer

# %%
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ##### This is another example of time unit conversion: converting minutes to hours

# %%
# Assign the minutes value to a variable
minutes = 200

# Conversion factor: 1 hour = 60 minutes
conversion_factor = 60

# Calculate the hours
hours = minutes / conversion_factor

# Print the result
print(f"{minutes} minutes is equal to {hours} hours.")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours.

# %% [markdown]
# ## Author
# **Chidera Okonkwo-Samuel**
